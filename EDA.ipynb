# %%
import pandas as pd
import zipfile

# %%
import pandas as pd

df = pd.read_csv(
    "psgs_sample_500.tsv",
    sep="\t",
    engine="python",
    on_bad_lines="skip"
)

df.head()
# Out:
#    id                                               text  \
# 0   0  Academy Award for Best Production Design\nThe ...
# 1   1  The films below are listed with their producti...
# 2   2  Animalia (book)\nAnimalia is an illustrated ch...
# 3   3  from the animal kingdom (A is for alligator, B...
# 4   4  book version for children the same year.\nH. N...
#
#                             wikipedia_title  wikipedia_id  end_paragraph  \
# 0  Academy Award for Best Production Design           316              1
# 1  Academy Award for Best Production Design           316              5
# 2                           Animalia (book)           332              3
# 3                           Animalia (book)           332              5
# 4                           Animalia (book)           332              9
#
#    end_character
# 0            480
# 1             63
# 2            156
# 3            120
# 4            178

# %%
df.shape
df.columns
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               155 non-null    int64
#  1   text             155 non-null    str
#  2   wikipedia_title  155 non-null    str
#  3   wikipedia_id     155 non-null    int64
#  4   end_paragraph    155 non-null    int64
#  5   end_character    155 non-null    int64
# dtypes: int64(4), str(2)
# memory usage: 7.4 KB

# %%
df["text"][0]
# Out:
# "Academy Award for Best Production Design\nThe Academy Award for Best Production Design recognizes achievement for art direction in film. The category's original name was Best Art Direction, but was changed to its current name in 2012 for the 85th Academy Awards. This change resulted from the Art Director's branch of the Academy of Motion Picture Arts and Sciences (AMPAS) being renamed the Designer's branch. Since 1947, the award is shared with the set decorator(s). It is awarded to the best interior design in a film."

# %%
df["wikipedia_title"][0]
# Out:
# 'Academy Award for Best Production Design'

# %%
df["text_length"] = df["text"].str.len()
df["text_length"].describe()
# Out:
# count    155.000000
# mean     500.683871
# std       64.736705
# min      110.000000
# 25%      477.000000
# 50%      511.000000
# 75%      540.500000
# max      615.000000
# Name: text_length, dtype: float64
